# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Biswajit1999/daily-astro-notebooks/blob/master/exoplanet-archive/2026-07-30-habitable-zone-kepler442/notebook.ipynb)
#
# # Is Kepler-442b really in its star's habitable zone?

# %% [markdown]
# Kepler-442b is frequently listed as one of the most Earth-like confirmed exoplanets, both in size and in how much starlight it receives. Rather than taking that reputation at face value, I pulled its real archive parameters and worked out the habitable zone boundaries for its host star myself, the same way I did for TRAPPIST-1 in an earlier notebook, to check the claim directly.

# %%
import pyvo as vo
import numpy as np

svc = vo.dal.TAPService('https://exoplanetarchive.ipac.caltech.edu/TAP')
query = '''
SELECT pl_name, pl_orbsmax, pl_rade, pl_eqt, st_teff, st_lum
FROM pscomppars
WHERE pl_name = 'Kepler-442 b'
'''
tab = svc.search(query).to_table()
print(tab)
# Out:
#   pl_name    pl_orbsmax   pl_rade    pl_eqt st_teff   st_lum
#                         Earth Radius   K       K    log(Solar)
# ------------ ---------- ------------ ------ ------- ----------
# Kepler-442 b      0.409         1.34  241.0  4402.0     -0.932

# %%
st_lum_log = tab['st_lum'][0]
L = 10**st_lum_log
hz_inner = np.sqrt(L/1.1)
hz_outer = np.sqrt(L/0.53)
a = tab['pl_orbsmax'][0]
radius = tab['pl_rade'][0]
teq = tab['pl_eqt'][0]

print(f'Host star luminosity: {L:.3f} solar luminosities')
print(f'Estimated habitable zone: {hz_inner:.3f} - {hz_outer:.3f} AU')
print(f'Kepler-442b orbital distance: {a:.3f} AU')
print(f'Planet radius: {radius:.2f} Earth radii')
print(f'Equilibrium temperature: {teq} K')
print('In habitable zone:', hz_inner <= a <= hz_outer)
# Out:
# Host star luminosity: 0.117 solar luminosities
# Estimated habitable zone: 0.326 - 0.470 AU
# Kepler-442b orbital distance: 0.409 AU
# Planet radius: 1.34 Earth radii
# Equilibrium temperature: 241.0 K
# In habitable zone: True

# %% [markdown]
# By this simple luminosity-based estimate, Kepler-442b really does land inside the habitable zone, and its radius (a bit larger than Earth's, in the 'super-Earth' range) is close enough to Earth-like that the planet's reputation checks out reasonably well from this quick calculation -- though 'habitable zone' only means liquid water is plausible given the energy balance, not that the planet is actually habitable, since we don't know if it has an atmosphere at all.

# %% [markdown]
# **What I'd look at next:** Look up whether Kepler-442b's mass has ever been measured (many Kepler planets only have a radius, not a mass, since Kepler used the transit method), since mass determines whether a planet is more likely rocky or a mini-Neptune with a thick gas envelope.
#
# **Citation:** This research has made use of the NASA Exoplanet Archive, which is operated by the California Institute of Technology, under contract with NASA under the Exoplanet Exploration Program. See https://exoplanetarchive.ipac.caltech.edu/docs/acknowledge.html.
